# %%
import pandas as pd
import great_expectations as ge

# %%
df = pd.read_csv("../data/medical_aid_claims.csv")

# %%
df_v = ge.from_pandas(df)

# %%
df_v.head()
# Out:
#   member-name                     email  gender   location   employer  \
# 0       Chipi        ajimmison0@sun.com  female     Kwekwe       Vipe
# 1       Femba     rsoonhouse1@google.it  female  Marondera       Mudo
# 2        Geta  bchecchetelli2@house.gov  female     Rusape     Skaboo
# 3    Tichaona          mgarman3@psu.edu  female     Rusape  Babbleset
# 4       Chisa     ccough4@biglobe.ne.jp  female   Bulawayo   Flipopia
#
#   relationship patient_name  patient_suffix patient_dob  \
# 0  Grandfather      Mabhena             789   9/11/1997
# 1      Husband      Sithole             860   1/14/1992
# 2       Mother        Chipi             374    7/3/1999
# 3       Father       Jembwa             729   7/31/1978
# 4       Father         Foto             716  12/28/1992
#
#                    cause  Fee Charged  membership_period  number_of_claims  \
# 0                  Other         3798               1541                 2
# ...

# %%
df_v.expect_column_values_to_be_unique(column="member-name")
# Out:
# {
#   "success": false,
#   "result": {
#     "element_count": 7000,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 7000,
#     "unexpected_percent": 100.0,
#     "unexpected_percent_nonmissing": 100.0,
#     "partial_unexpected_list": [
#       "Chipi",
#       "Femba",
#       "Geta",
#       "Tichaona",
#       "Chisa",
#       "Gweta",
#       "Konde",
#       "Gweta",
#       "Sibanda",
#       "Evans",
#       "Konde",
#       "Tichaona",
#       "Mabhena",
#       "Peterson",
#       "Konde",
#       "Sithole",
#       "Mabhena",
#       "Mabhena",
#       "Foto",
#       "Sithole"
#     ]
#   },
#   "exception_info": null,
#   "meta": {}
# }

# %%
df_v.expect_column_values_to_be_between(
    column="FeeChsrged", min_value=1000, max_value=50000
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/pip_packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /tmp/pip_packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /tmp/pip_packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FeeChsrged'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_48/2513358416.py in <module>
# ...

# %%
df_v["FeeC"]
# Out:
#       member-name                     email  gender   location   employer  \
# 0           Chipi        ajimmison0@sun.com  female     Kwekwe       Vipe
# 1           Femba     rsoonhouse1@google.it  female  Marondera       Mudo
# 2            Geta  bchecchetelli2@house.gov  female     Rusape     Skaboo
# 3        Tichaona          mgarman3@psu.edu  female     Rusape  Babbleset
# 4           Chisa     ccough4@biglobe.ne.jp  female   Bulawayo   Flipopia
# ...           ...                       ...     ...        ...        ...
# 6995        Mirwa    gcobbern@microsoft.com    male     Kwekwe     Trudeo
# 6996  Chisa Chisi   ebrasierro@sakura.ne.jp    male      Gweru    Jetwire
# 6997        Evans     ybuckyrp@slashdot.org    male     Rusape  Realpoint
# 6998        Femba   raskawrq@washington.edu  female      Gweru     Eimbee
# 6999      Sithole     wlantrr@quantcast.com    male      Gweru    Camimbo
#
#      relationship patient_name  patient_suffix patient_dob  \
# ...
